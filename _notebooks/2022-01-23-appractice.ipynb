// %% [markdown]
// # AP Practice
//
// - title : AP Practice
// - toc: true
// - badges: true
// - comments: true
// - categories: [jupyter]

// %% [markdown]
// # Quiz Results: 48/52
// > My Experience :
// I felt like this one was easier than the one before, and it also took me a lot less time to finish. Most of the questions were asking about output of a program and something wrong with the program, fix it. The main reason I got points it because I didn't properly read through the entire code and hence missed some things like + 1 or not noticing of what variable was being printed.

// %% [markdown]
// # Test Corrections:
//
// ![image.png](attachment:image.png)
//
// In this problem, I didn't consider all the answer choices and due to logic error, I picked the wrong answer. After thinking, I think the correct choice is E because after "A" get detected, since indexOf() gives the first occurance of "A", everything before should be eliminated to consider the new string.
//
// ![image.png](attachment:image-2.png)
//
// I didn't do this problem properly because I though this would take up a lot of time and hence I guessed on it.
//
// ![image.png](attachment:image-3.png)
//
// I didn't notice the k was the variable being printed, instead i thought the value at that index is being printed.
//
// ![image.png](attachment:image-4.png)
//
// I didn't notice the +1 after the variable howfar.
